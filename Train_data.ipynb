# %% [markdown]
# <a href="https://colab.research.google.com/github/TechWizard101/GDDA612/blob/main/Train_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
#  BL-Flickr-Images-Book.csv   hw1.ipynb      olympics.gsheet  'train .txt.csv'
#  heart.csv                   olympics.csv   olympics.ipynb   'Week 3 - olympics.ipynb'

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('train .txt.csv')
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  376          30       RL          NaN    10020   Pave   NaN      IR1
# 1  376          30       RL          NaN    10020   Pave   NaN      IR1
# 2   89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 3  251          30       RL         55.0     5350   Pave   NaN      IR1
# 4  379          20       RL         88.0    11394   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Lvl    AllPub  ...        0    NaN   GdWo        Shed     450
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2742 entries, 0 to 2741
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2742 non-null   int64
#  1   MSSubClass     2742 non-null   int64
#  2   MSZoning       2742 non-null   object
#  3   LotFrontage    2254 non-null   float64
#  4   LotArea        2742 non-null   int64
#  5   Street         2742 non-null   object
#  6   Alley          167 non-null    object
#  7   LotShape       2742 non-null   object
#  8   LandContour    2742 non-null   object
#  9   Utilities      2742 non-null   object
#  10  LotConfig      2742 non-null   object
#  11  LandSlope      2742 non-null   object
#  12  Neighborhood   2742 non-null   object
#  13  Condition1     2742 non-null   object
#  14  Condition2     2742 non-null   object
#  15  BldgType       2742 non-null   object
#  16  HouseStyle     2742 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2742.000000  2742.000000  2254.000000    2742.000000  2742.000000
# mean    708.057987    57.076951    70.122449   10544.546681     6.103574
# std     399.059603    42.411557    24.518082   10205.723684     1.381404
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     364.000000    20.000000    59.000000    7577.000000     5.000000
# 50%     706.500000    50.000000    70.000000    9468.500000     6.000000
# 75%    1049.000000    70.000000    80.000000   11613.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2742.000000  2742.000000   2742.000000  2726.000000  2742.000000  ...
# mean      5.571481  1971.367980   1984.813640   103.952678   444.362874  ...
# std       1.116277    30.068496     20.616526   182.242310   458.165871  ...
# ...

# %%
df.shape
# Out:
# (2742, 81)

# %%
duplicate_rows=df.duplicated()
df.duplicated().sum()
# Out:
# 1282

# %%
df.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False         True    False   False   True
# 1     False       False     False         True    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 2737  False       False     False        False    False   False  False
# 2738  False       False     False        False    False   False   True
# 2739  False       False     False        False    False   False   True
# 2740  False       False     False         True    False   False   True
# 2741  False       False     False         True    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      488
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.797228
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
df.duplicated().sum()
# Out:
# 1282

# %%
df.duplicated().sum()/df.shape[0]*100
# Out:
# 46.75419401896426

# %%
for i in df.select_dtypes(include="object").columns:
 print(df[i].value_counts())
 print('***'*10)
# Out:
# MSZoning
# RL         2164
# RM          404
# FV          124
# RH           31
# C (all)      19
# Name: count, dtype: int64
# ******************************
# Street
# Pave    2730
# Grvl      12
# Name: count, dtype: int64
# ******************************
# Alley
# Grvl    91
# Pave    76
# Name: count, dtype: int64
# ******************************
# LotShape
# Reg    1731
# IR1     914
# IR2      79
# IR3      18
# Name: count, dtype: int64
# ******************************
# LandContour
# Lvl    2461
# Bnk     117
# HLS      95
# Low      69
# Name: count, dtype: int64
# ******************************
# Utilities
# AllPub    2740
# NoSeWa       2
# Name: count, dtype: int64
# ******************************
# LotConfig
# Inside     1976
# Corner      496
# CulDSac     177
# FR2          86
# FR3           7
# Name: count, dtype: int64
# ******************************
# LandSlope
# Gtl    2594
# Mod     123
# Sev      25
# Name: count, dtype: int64
# ...

# %%
df.describe(include="int64").T
# Out:
#                 count           mean           std      min       25%  \
# Id             2742.0     708.057987    399.059603      1.0     364.0
# MSSubClass     2742.0      57.076951     42.411557     20.0      20.0
# LotArea        2742.0   10544.546681  10205.723684   1300.0    7577.0
# OverallQual    2742.0       6.103574      1.381404      1.0       5.0
# OverallCond    2742.0       5.571481      1.116277      1.0       5.0
# YearBuilt      2742.0    1971.367980     30.068496   1872.0    1954.0
# YearRemodAdd   2742.0    1984.813640     20.616526   1950.0    1967.0
# BsmtFinSF1     2742.0     444.362874    458.165871      0.0       0.0
# BsmtFinSF2     2742.0      46.620715    161.200437      0.0       0.0
# BsmtUnfSF      2742.0     567.743618    442.386981      0.0     225.0
# TotalBsmtSF    2742.0    1058.727206    441.372473      0.0     796.0
# 1stFlrSF       2742.0    1162.624726    387.790788    334.0     882.0
# ...

# %%
duplicate_rows = df[df.duplicated()]
# Remove duplicate rows from the DataFrame
cleaned_df = df.drop_duplicates()
# Print out the duplicate rows (if any)
if not duplicate_rows.empty:
    print("Duplicate rows:")
    print(duplicate_rows)
else:
    print("No duplicate rows found.")
# Out:
# Duplicate rows:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1      376          30       RL          NaN    10020   Pave   NaN      IR1
# 7       89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 8      251          30       RL         55.0     5350   Pave   NaN      IR1
# 9      379          20       RL         88.0    11394   Pave   NaN      Reg
# 10     399          30       RM         60.0     8967   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 2737   992          70       RM        121.0    17671   Pave  Grvl      Reg
# 2738  1124          20       RL         50.0     9405   Pave   NaN      Reg
# 2739  1150          70       RM         50.0     9000   Pave   NaN      Reg
# 2740  1214          80       RL          NaN    10246   Pave   NaN      IR1
# 2741  1269          50       RL          NaN    14100   Pave   NaN      IR1
#
# ...
